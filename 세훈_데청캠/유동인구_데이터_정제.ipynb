# %% [markdown]
# <a href="https://colab.research.google.com/github/ansehoon1999/DataCampusProject/blob/main/%EC%84%B8%ED%9B%88_%EB%8D%B0%EC%B2%AD%EC%BA%A0/%EC%9C%A0%EB%8F%99%EC%9D%B8%EA%B5%AC_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%95%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

path = "/content/drive/MyDrive/2019년"

file_list = os.listdir(path)
file_list_py = [file for file in file_list]

data_file = []
path_s_list = [] #세부 경로

print(file_list_py)

for i in range(len(file_list_py)) :
  path_s = path + '/' + file_list_py[i]
  path_s_list.append(path_s)

print(path_s_list)

for i in range(len(file_list_py)) :
  path_s = path + '/' + file_list_py[i]
  file_list_s = os.listdir(path_s)
  file_list_py_s = [path_s + '/' + file  for file in file_list_s]
  data_file.append(file_list_py_s)  
  print(data_file)
# Out:
# ['2019년_1월', '2019년_2월', '2019년_3월', '2019년_4월', '2019년_5월', '2019년_6월', '2019년_7월', '2019년_8월', '2019년_9월', '2019년_10월', '2019년_11월', '2019년_12월']
# ['/content/drive/MyDrive/2019년/2019년_1월', '/content/drive/MyDrive/2019년/2019년_2월', '/content/drive/MyDrive/2019년/2019년_3월', '/content/drive/MyDrive/2019년/2019년_4월', '/content/drive/MyDrive/2019년/2019년_5월', '/content/drive/MyDrive/2019년/2019년_6월', '/content/drive/MyDrive/2019년/2019년_7월', '/content/drive/MyDrive/2019년/2019년_8월', '/content/drive/MyDrive/2019년/2019년_9월', '/content/drive/MyDrive/2019년/2019년_10월', '/content/drive/MyDrive/2019년/2019년_11월', '/content/drive/MyDrive/2019년/2019년_12월']
# ...

# %%
def chain(*iterables):
    # chain('ABC', 'DEF') --> ['A', 'B', 'C', 'D', 'E', 'F']
    for it in iterables:
        for element in it:
            yield element

# %%
import numpy as np
import itertools

result_list = list(itertools.chain(*data_file))
result_list.reverse()
result_list
# Out:
# ['/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191231.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191230.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191229.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191228.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191227.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191224.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191226.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191225.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191223.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191222.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191221.csv',
#  '/content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191220.csv',
# ...

# %%
print(len(result_list))
# Out:
# 346

# %%
import pandas as pd

#빈 데이터 프레임 만들기
df_result = pd.DataFrame({'시간대구분':[15],
                             '집계구코드':[1101072010001],
                             '총생활인구수':[0]})
print(df_result)
# Out:
#    시간대구분          집계구코드  총생활인구수
# 0     15  1101072010001       0

# %%
for i in range(len(result_list)) :
  df = pd.read_csv(result_list[i])
  df = df[['시간대구분', '집계구코드', '총생활인구수']]
  #15시만 뽑아내기
  df_time = df['시간대구분'] == 15
  df_time_s = df[df_time]
  
  df_result = pd.concat([df_result,df_time_s])
  print( result_list[i], " ", len(df_result))
# Out:
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191231.csv   19154
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191230.csv   38307
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191229.csv   57459
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191228.csv   76612
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191227.csv   95765
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191224.csv   114918
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191226.csv   134071
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191225.csv   153223
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191223.csv   172376
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191222.csv   191529
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191221.csv   210682
# /content/drive/MyDrive/2019년/2019년_12월/LOCAL_PEOPLE_20191220.csv   229835
# ...

# %%
import math 

df_result = df_result[['집계구코드', '총생활인구수']]

df_code = df_result['집계구코드']
df = df_result.groupby(df_result['집계구코드'])
df_final = round(pd.DataFrame(df.mean()))

tmp = []

for i in range(len(df_final)) :
  tmp.append(df_final.iloc[i,0