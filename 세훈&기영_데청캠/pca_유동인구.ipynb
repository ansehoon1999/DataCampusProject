# %% [markdown]
# <a href="https://colab.research.google.com/github/ansehoon1999/DataCampusProject/blob/main/%EC%84%B8%ED%9B%88%26%EA%B8%B0%EC%98%81_%EB%8D%B0%EC%B2%AD%EC%BA%A0/pca_%EC%9C%A0%EB%8F%99%EC%9D%B8%EA%B5%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file1 = '/content/drive/MyDrive/2019년_유동인구_6시.txt'
file2 = '/content/drive/MyDrive/2019년_유동인구_9시.txt'
file3 = '/content/drive/MyDrive/2019년_유동인구_12시.txt'
file4 = '/content/drive/MyDrive/2019년_유동인구_15시.txt'
file5 = '/content/drive/MyDrive/2019년_유동인구_18시.txt'
file6 = '/content/drive/MyDrive/2019년_유동인구_21시.txt'



col2_1 = []
col4_1 = []


f1 = open(file1, 'r')
line = f1.readline()

while True:

    line = f1.readline()
    if not line: 
      break

    l = line.split('^')

    col2_1.append(l[1])
    col4_1.append(float(l[3]))

#===================================================================


col2_2 = []
col4_2 = []


f2 = open(file2, 'r')
line = f2.readline()

while True:

    line = f2.readline()
    if not line: 
      break

    l = line.split('^')

    col2_2.append(l[1])
    col4_2.append(float(l[3]))

#===================================================================


col2_3 = []
col4_3 = []


f3 = open(file3, 'r')
line = f3.readline()

while True:

    line = f3.readline()
    if not line: 
      break

    l = line.split('^')

    col2_3.append(l[1])
    col4_3.append(float(l[3]))

#===================================================================


col2_4 = []
col4_4 = []


f4 = open(file4, 'r')
line = f4.readline()

while True:

    line = f4.readline()
    if not line: 
      break

    l = line.split('^')

    col2_4.append(l[1])
    col4_4.append(float(l[3]))

#===================================================================


col2_5 = []
col4_5 = []


f5 = open(file5, 'r')
line = f5.readline()

while True:

    line = f5.readline()
    if not line: 
      break

    l = line.split('^')
    col2_5.append(l[1])
    col4_5.append(float(l[3]))

#===================================================================

col2_6 = []
col4_6 = []


f6 = open(file6, 'r')
line = f6.readline()

while True:

    line = f6.readline()
    if not line: 
      break

    l = line.split('^')
    col2_6.append(l[1])
    col4_6.append(float(l[3]))

# %%
import pandas as pd


df1 = pd.DataFrame({
    "집계구코드": col2_1,
    "6시유동인구": col4_1,
    })
df2 = pd.DataFrame({
    "집계구코드": col2_2,
    "9시유동인구": col4_2,
    })
df3 = pd.DataFrame({
    "집계구코드": col2_3,
    "12시유동인구": col4_3,
    })
df4 = pd.DataFrame({
    "집계구코드": col2_4,
    "15시유동인구": col4_4,
    })
df5 = pd.DataFrame({
    "집계구코드": col2_5,
    "18시유동인구": col4_5,
    })
df6 = pd.DataFrame({
    "집계구코드": col2_6,
    "21시유동인구": col4_6,
    })

df1.set_index('집계구코드', inplace = True)
df2.set_index('집계구코드', inplace = True)
df3.set_index('집계구코드', inplace = True)
df4.set_index('집계구코드', inplace = True)
df5.set_index('집계구코드', inplace = True)
df6.set_index('집계구코드', inplace = True)

print(df1)
print(df2)
print(df3)
print(df4)
print(df5)
print(df6)

x = df1.join(df2, how='right')
x = x.join(df3, how='right')
x = x.join(df4, how='right')
x = x.join(df5, how='right')
x = x.join(df6, how='right')
x
# Out:
#                6시유동인구
# 집계구코드
# 1101053010001   279.0
# 1101053010002  1789.0
# 1101053010003  1870.0
# 1101053010004  3062.0
# 1101053010005  2783.0
# ...               ...
# 1125074030501   112.0
# 1125074030701   336.0
# 1125074030801   311.0
# 1125074031101   104.0
# 1125074033301    80.0
#
# [19153 rows x 1 columns]
#                9시유동인구
# 집계구코드
# 1101053010001   296.0
# 1101053010002  1798.0
# 1101053010003  1591.0
# 1101053010004  2476.0
# 1101053010005  1907.0
# ...               ...
# 1125074030501   222.0
# 1125074030701   617.0
# 1125074030801   359.0
# 1125074031101   190.0
# 1125074033301   156.0
#
# [19153 rows x 1 columns]
#                12시유동인구
# 집계구코드
# 1101053010001    294.0
# 1101053010002   1896.0
# 1101053010003   1774.0
# 1101053010004   3071.0
# 1101053010005   2401.0
# ...                ...
# 1125074030501    146.0
# 1125074030701    427.0
# 1125074030801    329.0
# 1125074031101    141.0
# 1125074033301    105.0
#
# [19153 rows x 1 columns]
#                15시유동인구
# 집계구코드
# 1101053010001    279.0
# 1101053010002   1789.0
# 1101053010003   1870.0
# 1101053010004   3062.0
# 1101053010005   2783.0
# ...                ...
# 1125074030501    112.0
# 1125074030701    336.0
# 1125074030801    311.0
# 1125074031101    104.0
# 1125074033301     80.0
#
# [19153 rows x 1 columns]
#                18시유동인구
# 집계구코드
# 1101053010001    295.0
# 1101053010002   1859.0
# 1101053010003   1566.0
# 1101053010004   3107.0
# 1101053010005   2185.0
# ...                ...
# 1125074030501    126.0
# 1125074030701    449.0
# 1125074030801    349.0
# 1125074031101    145.0
# 1125074033301    100.0
#
# [19153 rows x 1 columns]
#                21시유동인구
# 집계구코드
# 1101053010001    300.0
# 1101053010002   1887.0
# 1101053010003   1218.0
# 1101053010004   2138.0
# 1101053010005   1678.0
# ...                ...
# 1125074030501    313.0
# 1125074030701   1083.0
# 1125074030801    578.0
# 1125074031101    325.0
# 1125074033301    220.0
#
# [19153 rows x 1 columns]
#                6시유동인구  9시유동인구  12시유동인구  15시유동인구  18시유동인구  21시유동인구
# 집계구코드
# 1101053010001   279.0   296.0    294.0    279.0    295.0    300.0
# 1101053010002  1789.0  1798.0   1896.0   1789.0   1859.0   1887.0
# 1101053010003  1870.0  1591.0   1774.0   1870.0   1566.0   1218.0
# 1101053010004  3062.0  2476.0   3071.0   3062.0   3107.0   2138.0
# 1101053010005  2783.0  1907.0   2401.0   2783.0   2185.0   1678.0
# ...               ...     ...      ...      ...      ...      ...
# 1125074030501   112.0   222.0    146.0    112.0    126.0    313.0
# 1125074030701   336.0   617.0    427.0    336.0    449.0   1083.0
# 1125074030801   311.0   359.0    329.0    311.0    349.0    578.0
# 1125074031101   104.0   190.0    141.0    104.0    145.0    325.0
# 1125074033301    80.0   156.0    105.0     80.0    100.0    220.0
#
# [19153 rows x 6 columns]

# %%
x.corr()
# Out:
#            6시유동인구    9시유동인구   12시유동인구   15시유동인구   18시유동인구   21시유동인구
# 6시유동인구   1.000000  0.977088  0.997185  1.000000  0.979791  0.905007
# 9시유동인구   0.977088  1.000000  0.985630  0.977088  0.954352  0.911252
# 12시유동인구  0.997185  0.985630  1.000000  0.997185  0.971310  0.899028
# 15시유동인구  1.000000  0.977088  0.997185  1.000000  0.979791  0.905007
# 18시유동인구  0.979791  0.954352  0.971310  0.979791  1.000000  0.955260
# 21시유동인구  0.905007  0.911252  0.899028  0.905007  0.955260  1.000000

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()
fitted = min_max_scaler.fit(x)
print(fitted.data_max_)
print(fitted.data_min_)

output = min_max_scaler.transform(x)
output = pd.DataFrame(output, columns=x.columns, index=list(x.index.values))
output = output.dropna(axis=0)
output
# Out:
# [53703. 45093. 54040. 53703. 41757. 28527.]
# [1. 1. 1. 1. 1. 0.]
#                  6시유동인구    9시유동인구   12시유동인구   15시유동인구   18시유동인구   21시유동인구
# 1101053010001  0.005177  0.006542  0.005422  0.005177  0.007041  0.010516
# 1101053010002  0.033295  0.039852  0.035067  0.033295  0.044497  0.066148
# 1101053010003  0.034803  0.035261  0.032810  0.034803  0.037480  0.042696
# 1101053010004  0.057000  0.054888  0.056811  0.057000  0.074385  0.074947
# 1101053010005  0.051804  0.042269  0.044412  0.051804  0.052304  0.058821
# ...                 ...       ...       ...       ...       ...       ...
# 1125074030501  0.002067  0.004901  0.002683  0.002067  0.002994  0.010972
# 1125074030701  0.006238  0.013661  0.007883  0.006238  0.010729  0.037964
# 1125074030801  0.005773  0.007939  0.006070  0.005773  0.008334  0.020262
# 1125074031101  0.001918  0.004191  0.002591  0.001918  0.003449  0.011393
# 1125074033301  0.001471  0.003437  0.001925  0.001471  0.002371  0.007712
#
# [19153 rows x 6 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(output)
PC_score = pca.transform(output)
PC_score


pc1 = []
pc2 = []
pc3 = []
pc4 = []
pc5 = []
pc6 = []


for i in range(len(PC_score)) :
  for j in range(6) :
    if j == 0 :
      pc1.append(PC_score[i][0])
    elif j == 1:
      pc2.append(PC_score[i][1])
    elif j == 2:
      pc3.append(PC_score[i][2])
    elif j == 3:
      pc4.append(PC_score[i][3])
    elif j == 4:
      pc5.append(PC_score[i][4])
    elif j == 5:
      pc6.append(PC_score[i][5])

pc_result = pd.DataFrame({
    'PC1': pc1,
    'PC2': pc2,
    'PC3': pc3,
    'PC4': pc4,
    'PC5': pc5,
    'PC6': pc6,

})
pc_result
# Out:
#             PC1       PC2       PC3       PC4       PC5           PC6
# 0     -0.015369 -0.002608  0.001048 -0.000153 -0.000173  4.142922e-19
# 1      0.071760  0.017792 -0.006457  0.000474 -0.001932 -2.558039e-18
# 2      0.057312 -0.001996 -0.001791  0.000348  0.000869  4.856917e-18
# 3      0.122167  0.006614  0.003554 -0.004642 -0.002989  8.647057e-18
# 4      0.091780 -0.000981  0.003149  0.005141  0.003140  9.408167e-18
# ...         ...       ...       ...       ...       ...           ...
# 19148 -0.021186  0.000075 -0.000896  0.000986 -0.000062 -1.875535e-18
# 19149  0.002413  0.017984 -0.007236  0.003962 -0.000540 -5.548100e-18
# 19150 -0.009386  0.004852 -0.000941  0.001922 -0.000200 -1.937573e-18
# 19151 -0.021223  0.000735 -0.000224  0.001024 -0.000284 -1.587115e-18
# 19152 -0.024173 -0.001874  0.000332  0.000517 -0.000073 -1.396568e-18
#
# [19153 rows x 6 columns]

# %%
ratio = pca.explained_variance_ratio_
ratio


df_v = pd.DataFrame(ratio, index=['PC1','PC2','PC3','PC4', 'PC5', 'PC6'], columns=['V_ration'])
df_v.plot.pie(y='V_ration')
df_v
# Out:
#          V_ration
# PC1  9.647720e-01
# PC2  2.758975e-02
# PC3  6.396436e-03
# PC4  1.018749e-03
# PC5  2.231061e-04
# PC6  1.017952e-32

# %%
pca = PCA(n_components = 1) # feature 변수 개수가 2개
pca.fit(output)
PCscore = pca.transform(output)
PCscore

pc1 = []
pc2 = []


for i in range(len(PC_score)) :
  for j in range(6) :
    if j == 0 :
      pc1.append(PC_score[i][0])
    elif j == 1:
      pc2.append(PC_score[i][1])

pc_result = pd.DataFrame({
    'PC1': pc1,
    'PC2': pc2,
})
pc_result
