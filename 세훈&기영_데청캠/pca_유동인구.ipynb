# %% [markdown]
# <a href="https://colab.research.google.com/github/ansehoon1999/DataCampusProject/blob/main/%EC%84%B8%ED%9B%88%26%EA%B8%B0%EC%98%81_%EB%8D%B0%EC%B2%AD%EC%BA%A0/pca_%EC%9C%A0%EB%8F%99%EC%9D%B8%EA%B5%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file1 = '/content/drive/MyDrive/2019년_유동인구_6찐시.txt'
file2 = '/content/drive/MyDrive/2019년_유동인구_9시.txt'
file3 = '/content/drive/MyDrive/2019년_유동인구_12시.txt'
file4 = '/content/drive/MyDrive/2019년_유동인구_15시.txt'
file5 = '/content/drive/MyDrive/2019년_유동인구_18시.txt'
file6 = '/content/drive/MyDrive/2019년_유동인구_21시.txt'



col2_1 = []
col4_1 = []


f1 = open(file1, 'r')
line = f1.readline()

while True:

    line = f1.readline()
    if not line: 
      break

    l = line.split('^')

    col2_1.append(l[1])
    col4_1.append(float(l[3]))

#===================================================================


col2_2 = []
col4_2 = []


f2 = open(file2, 'r')
line = f2.readline()

while True:

    line = f2.readline()
    if not line: 
      break

    l = line.split('^')

    col2_2.append(l[1])
    col4_2.append(float(l[3]))

#===================================================================


col2_3 = []
col4_3 = []


f3 = open(file3, 'r')
line = f3.readline()

while True:

    line = f3.readline()
    if not line: 
      break

    l = line.split('^')

    col2_3.append(l[1])
    col4_3.append(float(l[3]))

#===================================================================


col2_4 = []
col4_4 = []


f4 = open(file4, 'r')
line = f4.readline()

while True:

    line = f4.readline()
    if not line: 
      break

    l = line.split('^')

    col2_4.append(l[1])
    col4_4.append(float(l[3]))

#===================================================================


col2_5 = []
col4_5 = []


f5 = open(file5, 'r')
line = f5.readline()

while True:

    line = f5.readline()
    if not line: 
      break

    l = line.split('^')
    col2_5.append(l[1])
    col4_5.append(float(l[3]))

#===================================================================

col2_6 = []
col4_6 = []


f6 = open(file6, 'r')
line = f6.readline()

while True:

    line = f6.readline()
    if not line: 
      break

    l = line.split('^')
    col2_6.append(l[1])
    col4_6.append(float(l[3]))

# %%
import pandas as pd


df1 = pd.DataFrame({
    "집계구코드": col2_1,
    "6시유동인구": col4_1,
    })
df2 = pd.DataFrame({
    "집계구코드": col2_2,
    "9시유동인구": col4_2,
    })
df3 = pd.DataFrame({
    "집계구코드": col2_3,
    "12시유동인구": col4_3,
    })
df4 = pd.DataFrame({
    "집계구코드": col2_4,
    "15시유동인구": col4_4,
    })
df5 = pd.DataFrame({
    "집계구코드": col2_5,
    "18시유동인구": col4_5,
    })
df6 = pd.DataFrame({
    "집계구코드": col2_6,
    "21시유동인구": col4_6,
    })
print(len(col2_1))

df1.set_index('집계구코드', inplace = True)
df2.set_index('집계구코드', inplace = True)
df3.set_index('집계구코드', inplace = True)
df4.set_index('집계구코드', inplace = True)
df5.set_index('집계구코드', inplace = True)
df6.set_index('집계구코드', inplace = True)

print(df1)
print(df2)
print(df3)
print(df4)
print(df5)
print(df6)

x = df1.join(df2, how='right')
x = x.join(df3, how='right')
x = x.join(df4, how='right')
x = x.join(df5, how='right')
x = x.join(df6, how='right')
x
# Out:
# 19153
#                6시유동인구
# 집계구코드
# 1101053010001   302.0
# 1101053010002  1711.0
# 1101053010003  1258.0
# 1101053010004  1355.0
# 1101053010005   914.0
# ...               ...
# 1125074030501   524.0
# 1125074030701  1081.0
# 1125074030801   528.0
# 1125074031101   309.0
# 1125074033301   277.0
#
# [19153 rows x 1 columns]
#                9시유동인구
# 집계구코드
# 1101053010001   296.0
# 1101053010002  1798.0
# 1101053010003  1591.0
# 1101053010004  2476.0
# 1101053010005  1907.0
# ...               ...
# 1125074030501   222.0
# 1125074030701   617.0
# 1125074030801   359.0
# 1125074031101   190.0
# 1125074033301   156.0
#
# [19153 rows x 1 columns]
#                12시유동인구
# 집계구코드
# 1101053010001    294.0
# 1101053010002   1896.0
# 1101053010003   1774.0
# 1101053010004   3071.0
# 1101053010005   2401.0
# ...                ...
# 1125074030501    146.0
# 1125074030701    427.0
# 1125074030801    329.0
# 1125074031101    141.0
# 1125074033301    105.0
#
# [19153 rows x 1 columns]
#                15시유동인구
# 집계구코드
# 1101053010001    279.0
# 1101053010002   1789.0
# 1101053010003   1870.0
# 1101053010004   3062.0
# 1101053010005   2783.0
# ...                ...
# 1125074030501    112.0
# 1125074030701    336.0
# 1125074030801    311.0
# 1125074031101    104.0
# 1125074033301     80.0
#
# [19153 rows x 1 columns]
#                18시유동인구
# 집계구코드
# 1101053010001    295.0
# 1101053010002   1859.0
# 1101053010003   1566.0
# 1101053010004   3107.0
# 1101053010005   2185.0
# ...                ...
# 1125074030501    126.0
# 1125074030701    449.0
# 1125074030801    349.0
# 1125074031101    145.0
# 1125074033301    100.0
#
# [19153 rows x 1 columns]
#                21시유동인구
# 집계구코드
# 1101053010001    300.0
# 1101053010002   1887.0
# 1101053010003   1218.0
# 1101053010004   2138.0
# 1101053010005   1678.0
# ...                ...
# 1125074030501    313.0
# 1125074030701   1083.0
# 1125074030801    578.0
# 1125074031101    325.0
# 1125074033301    220.0
#
# [19153 rows x 1 columns]
#                6시유동인구  9시유동인구  12시유동인구  15시유동인구  18시유동인구  21시유동인구
# 집계구코드
# 1101053010001   302.0   296.0    294.0    279.0    295.0    300.0
# 1101053010002  1711.0  1798.0   1896.0   1789.0   1859.0   1887.0
# 1101053010003  1258.0  1591.0   1774.0   1870.0   1566.0   1218.0
# 1101053010004  1355.0  2476.0   3071.0   3062.0   3107.0   2138.0
# 1101053010005   914.0  1907.0   2401.0   2783.0   2185.0   1678.0
# ...               ...     ...      ...      ...      ...      ...
# 1125074030501   524.0   222.0    146.0    112.0    126.0    313.0
# 1125074030701  1081.0   617.0    427.0    336.0    449.0   1083.0
# 1125074030801   528.0   359.0    329.0    311.0    349.0    578.0
# 1125074031101   309.0   190.0    141.0    104.0    145.0    325.0
# 1125074033301   277.0   156.0    105.0     80.0    100.0    220.0
#
# [19153 rows x 6 columns]

# %%
x.corr()
# Out:
#            6시유동인구    9시유동인구   12시유동인구   15시유동인구   18시유동인구   21시유동인구
# 6시유동인구   1.000000  0.816623  0.751584  0.739708  0.769957  0.874970
# 9시유동인구   0.816623  1.000000  0.985630  0.977088  0.954352  0.911252
# 12시유동인구  0.751584  0.985630  1.000000  0.997185  0.971310  0.899028
# 15시유동인구  0.739708  0.977088  0.997185  1.000000  0.979791  0.905007
# 18시유동인구  0.769957  0.954352  0.971310  0.979791  1.000000  0.955260
# 21시유동인구  0.874970  0.911252  0.899028  0.905007  0.955260  1.000000

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()
fitted = min_max_scaler.fit(x)
print(fitted.data_max_)
print(fitted.data_min_)

output = min_max_scaler.transform(x)
output = pd.DataFrame(output, columns=x.columns, index=list(x.index.values))
output = output.dropna(axis=0)
output
# Out:
# [26787. 45093. 54040. 53703. 41757. 28527.]
# [0. 1. 1. 1. 1. 0.]
#                  6시유동인구    9시유동인구   12시유동인구   15시유동인구   18시유동인구   21시유동인구
# 1101053010001  0.011274  0.006542  0.005422  0.005177  0.007041  0.010516
# 1101053010002  0.063874  0.039852  0.035067  0.033295  0.044497  0.066148
# 1101053010003  0.046963  0.035261  0.032810  0.034803  0.037480  0.042696
# 1101053010004  0.050584  0.054888  0.056811  0.057000  0.074385  0.074947
# 1101053010005  0.034121  0.042269  0.044412  0.051804  0.052304  0.058821
# ...                 ...       ...       ...       ...       ...       ...
# 1125074030501  0.019562  0.004901  0.002683  0.002067  0.002994  0.010972
# 1125074030701  0.040355  0.013661  0.007883  0.006238  0.010729  0.037964
# 1125074030801  0.019711  0.007939  0.006070  0.005773  0.008334  0.020262
# 1125074031101  0.011535  0.004191  0.002591  0.001918  0.003449  0.011393
# 1125074033301  0.010341  0.003437  0.001925  0.001471  0.002371  0.007712
#
# [19153 rows x 6 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(x)
PC_score = pca.transform(x)
PC_score


pc1 = []
pc2 = []
pc3 = []
pc4 = []
pc5 = []
pc6 = []


for i in range(len(PC_score)) :
  for j in range(6) :
    if j == 0 :
      pc1.append(PC_score[i][0])
    elif j == 1:
      pc2.append(PC_score[i][1])
    elif j == 2:
      pc3.append(PC_score[i][2])
    elif j == 3:
      pc4.append(PC_score[i][3])
    elif j == 4:
      pc5.append(PC_score[i][4])
    elif j == 5:
      pc6.append(PC_score[i][5])

pc_result = pd.DataFrame({
    'PC1': pc1,
    'PC2': pc2,
    'PC3': pc3,
    'PC4': pc4,
    'PC5': pc5,
    'PC6': pc6,

})
pc_result
# Out:
#                PC1         PC2         PC3         PC4         PC5         PC6
# 0      -635.420344 -162.420710   47.016754  -21.506775    3.262142   -6.821975
# 1      2948.834437  905.609984 -185.713801   25.813373   30.729951  -94.713475
# 2      2451.940225  188.117642 -239.785223  150.297873  -49.105363   33.427443
# 3      5056.290685  179.867602  262.897811  -40.954269 -144.114710 -155.739753
# 4      3731.020976 -188.516647  193.047247   51.923768  167.677056  166.596571
# ...            ...         ...         ...         ...         ...         ...
# 19148  -864.050138   74.096366  -89.295631   56.796515   21.706959   -2.531644
# 19149     8.597406  777.509960 -146.875805  -29.454594  181.315151  -12.830977
# 19150  -435.372823  137.351484   31.360391  -14.103734   88.627876   -1.883793
# 19151  -905.814196  -55.647009   43.016102  -43.905915   61.681121   -7.016333
# 19152 -1005.686456 -125.216175   19.291068  -19.071427   29.140847   -0.004595
#
# [19153 rows x 6 columns]

# %%
ratio = pca.explained_variance_ratio_
ratio


df_v = pd.DataFrame(ratio, index=['PC1','PC2','PC3','PC4', 'PC5', 'PC6'], columns=['V_ration'])
df_v.plot.pie(y='V_ration')
df_v
# Out:
#      V_ration
# PC1  0.960416
# PC2  0.024823
# PC3  0.011910
# PC4  0.001705
# PC5  0.000859
# PC6  0.000287

# %%
pca = PCA(n_components = 1) # feature 변수 개수가 2개
pca.fit(output)
PCscore = pca.transform(output)
PCscore

pc1 = []

for i in range(len(PC_score)) :
  for j in range(6) :
    if j == 0 :
      pc1.append(PC_score[i][0])


df_final = pd.DataFrame({
    '집계구경계': col2_1,
    'PC1': pc1
})
df_final
# Out:
#                집계구경계          PC1
# 0      1101053010001  -635.420344
# 1      1101053010002  2948.834437
# 2      1101053010003  2451.940225
# 3      1101053010004  5056.290685
# 4      1101053010005  3731.020976
# ...              ...          ...
# 19148  1125074030501  -864.050138
# 19149  1125074030701     8.597406
# 19150  1125074030801  -435.372823
# 19151  1125074031101  -905.814196
# 19152  1125074033301 -1005.686456
#
# [19153 rows x 2 columns]

# %%
f = open('/content/drive/MyDrive/2019년_유동인구_final.txt', 'w')
f.write("base_year^tot_oa_cd^item^value\n")


for i in range(len(df_final)) :
  string = '2019' + '^' + str(df_final.iloc[i,0]) + '^' + '_' +  '^' + str(df_final.iloc[i,1]) + "\n"
  f.write(string)

f.close()
